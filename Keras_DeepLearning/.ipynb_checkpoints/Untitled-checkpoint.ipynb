# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras import optimizers
from keras import losses
from keras import metrics
from keras import models
from keras import layers
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense, Dropout
from keras import regularizers

dataset = pd.read_csv('C:/Users/natha/source/repos/CreateRNNTrainFiles/CreateRNNTrainFiles/Data/Output/test1.csv', delimiter = ',')

dataset[:10]
# Out:
#      Sentence PosTag                            Tag             Word
# 0           1     NN  Python (programming language)           python
# 1           1    VBZ                              S               is
# 2           1     DT                              S               an
# 3           1     JJ                              0      interpreted
# 4           1     NN                              0       high-level
# 5           1     NN                              0      programming
# 6           1     NN                              0         language
# 7           1     IN                              S              for
# 8           1     JJ                              0  general-purpose
# 9           1      .                           Punc                .
# 10          2    VBN     Created suo jure peeresses          created
# 11          2     IN                              S               by
# 12          2     NN                              0            guido
# 13          2     NN                              0              van
# 14          2     NN                            NaN           rossum
# 15          2     CC                              S              and
# 16          2     JJ                              S            first
# 17          2    VBN  Released from excommunication         released
# 18          2     IN                              S               in
# 19          2     CD                              0             1991
# 20          2      ,                              0                ,
# 21          2     NN                              0           python
# 22          2    VBZ                              S              has
# 23          2     DT                              S                a
# 24          2     NN                              0           design
# 25          2     NN                              0       philosophy
# 26          2    WDT                              S             that
# 27          2    VBZ                            NaN       emphasizes
# 28          2     NN                              0             code
# 29          2     NN              Readability tests      readability
# ..        ...    ...                            ...              ...
# 114         8     NN                              0           source
# 115         8     NN                              0         software
# 116         8    VBZ                           Punc                [
# 117         8     CD                              0               31
# 118         8     NN                           Punc                ]
# 119         8     CC                              S              and
# 120         8    VBZ                              S              has
# 121         8     DT                              S                a
# 122         8     JJ       Community-based forestry  community-based
# 123         8     NN                              0      development
# 124         8     NN                              0            model
# 125         8     IN                              S               as
# 126         8    VBP                              S               do
# 127         8     RB                              S           nearly
# 128         8     DT                              S              all
# 129         8    POS                            NaN               's
# 130         8     JJ                              S            other
# 131         8    NNS                            NaN  implementations
# 132         8      .                           Punc                .
# 133         9     NN                Python software           python
# 134         9     CC                              S              and
# 135         9     NN                              0          cpython
# 136         9    VBP                              S              are
# 137         9    VBN                   Managed care          managed
# 138         9     IN                              S               by
# 139         9     DT                              S              the
# 140         9     JJ                              0       non-profit
# 141         9     NN                              0         software
# 142         9     NN                              0       foundation
# 143         9      .                           Punc                .
#
# [144 rows x 4 columns]
